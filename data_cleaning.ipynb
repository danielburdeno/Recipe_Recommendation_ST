# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ast
from sklearn.metrics.pairwise import cosine_similarity
import re

# %%
# Load the data
recipes = pd.read_csv('data/RAW_recipes.csv')
recipes.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients
# 0  ['winter squash', 'mexican seasoning', 'mixed ...              7
# 1  ['prepared pizza crust', 'sausage patty', 'egg...              6
# 2  ['ground beef', 'yellow onions', 'diced tomato...             13
# 3  ['spreadable cheese with garlic and herbs', 'n...             11
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...              8

# %%
# Nutrition information (calories (#), total fat (PDV), sugar (PDV) , sodium (PDV) , protein (PDV) , saturated fat (PDV), total carbohydrates (PDV))

# %%
recipes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231637 entries, 0 to 231636
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            231636 non-null  object
#  1   id              231637 non-null  int64
#  2   minutes         231637 non-null  int64
#  3   contributor_id  231637 non-null  int64
#  4   submitted       231637 non-null  object
#  5   tags            231637 non-null  object
#  6   nutrition       231637 non-null  object
#  7   n_steps         231637 non-null  int64
#  8   steps           231637 non-null  object
#  9   description     226658 non-null  object
#  10  ingredients     231637 non-null  object
#  11  n_ingredients   231637 non-null  int64
# dtypes: int64(5), object(7)
# memory usage: 21.2+ MB

# %%
recipes.describe()
# Out:
#                   id       minutes  contributor_id        n_steps  \
# count  231637.000000  2.316370e+05    2.316370e+05  231637.000000
# mean   222014.708984  9.398546e+03    5.534885e+06       9.765499
# std    141206.635626  4.461963e+06    9.979141e+07       5.995128
# min        38.000000  0.000000e+00    2.700000e+01       0.000000
# 25%     99944.000000  2.000000e+01    5.690500e+04       6.000000
# 50%    207249.000000  4.000000e+01    1.736140e+05       9.000000
# 75%    333816.000000  6.500000e+01    3.982750e+05      12.000000
# max    537716.000000  2.147484e+09    2.002290e+09     145.000000
#
#        n_ingredients
# count  231637.000000
# mean        9.051153
# std         3.734796
# min         1.000000
# 25%         6.000000
# 50%         9.000000
# 75%        11.000000
# max        43.000000

# %%
recipes.isna().sum()
# Out:
# name                 1
# id                   0
# minutes              0
# contributor_id       0
# submitted            0
# tags                 0
# nutrition            0
# n_steps              0
# steps                0
# description       4979
# ingredients          0
# n_ingredients        0
# dtype: int64

# %%
# Going to drop nulls as I want description to be able to display to the user
recipes = recipes.dropna()
recipes.isna().sum()
# Out:
# name              0
# id                0
# minutes           0
# contributor_id    0
# submitted         0
# tags              0
# nutrition         0
# n_steps           0
# steps             0
# description       0
# ingredients       0
# n_ingredients     0
# dtype: int64

# %%
recipes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 226657 entries, 0 to 231636
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            226657 non-null  object
#  1   id              226657 non-null  int64
#  2   minutes         226657 non-null  int64
#  3   contributor_id  226657 non-null  int64
#  4   submitted       226657 non-null  object
#  5   tags            226657 non-null  object
#  6   nutrition       226657 non-null  object
#  7   n_steps         226657 non-null  int64
#  8   steps           226657 non-null  object
#  9   description     226657 non-null  object
#  10  ingredients     226657 non-null  object
#  11  n_ingredients   226657 non-null  int64
# dtypes: int64(5), object(7)
# memory usage: 22.5+ MB

# %%
# Need to look at all the tags, to be used as content features
recipes['tags'] = recipes['tags'].apply(ast.literal_eval)
tags = recipes['tags'].explode()
tags
# Out:
# 0         60-minutes-or-less
# 0               time-to-make
# 0                     course
# 0            main-ingredient
# 0                    cuisine
#                  ...
# 231636               dietary
# 231636          comfort-food
# 231636            taste-mood
# 231636                 sweet
# 231636    number-of-servings
# Name: tags, Length: 4045919, dtype: object

# %%
len(tags)
# Out:
# 4045919

# %%
tag_counts = tags.value_counts()
tags_filtered = tag_counts[tag_counts >  10000]
tags_filtered
# Out:
# tags
# preparation        225568
# time-to-make       220353
# course             213602
# main-ingredient    166456
# dietary            160444
#                     ...
# beverages           10913
# sweet               10503
# savory              10428
# potluck             10313
# potatoes            10052
# Name: count, Length: 80, dtype: int64

# %%
len(tags.unique())
# Out:
# 552

# %%
# Nutrition information (calories (#), total fat (PDV), sugar (PDV) , sodium (PDV) , protein (PDV) , saturated fat (PDV), total carbohydrates (PDV))
recipes['nutrition'] = recipes['nutrition'].apply(ast.literal_eval)
recipes[['calories', 'fat', 'sugar', 'sodium', 'protein', 'saturated_fat', 'carbohydrates']] = recipes['nutrition'].apply(pd.Series)
recipes = recipes.drop(columns=['nutrition'])
recipes.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  n_steps  \
# 0  [60-minutes-or-less, time-to-make, course, mai...       11
# 1  [30-minutes-or-less, time-to-make, course, mai...        9
# 2  [time-to-make, course, preparation, main-dish,...        6
# 3  [60-minutes-or-less, time-to-make, course, mai...       11
# 4  [weeknight, time-to-make, course, main-ingredi...        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients  calories  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...              7      51.5
# 1  ['prepared pizza crust', 'sausage patty', 'egg...              6     173.4
# 2  ['ground beef', 'yellow onions', 'diced tomato...             13     269.8
# 3  ['spreadable cheese with garlic and herbs', 'n...             11     368.1
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...              8     352.9
#
#     fat  sugar  sodium  protein  saturated_fat  carbohydrates
# 0   0.0   13.0     0.0      2.0            0.0            4.0
# 1  18.0    0.0    17.0     22.0           35.0            1.0
# 2  22.0   32.0    48.0     39.0           27.0            5.0
# 3  17.0   10.0     2.0     14.0            8.0           20.0
# 4   1.0  337.0    23.0      3.0            0.0           28.0

# %%
recipes['steps'] = recipes['steps'].apply(ast.literal_eval)
recipes['steps'][0]
# Out:
# ['make a choice and proceed with recipe',
#  'depending on size of squash , cut into half or fourths',
#  'remove seeds',
#  'for spicy squash , drizzle olive oil or melted butter over each cut squash piece',
#  'season with mexican seasoning mix ii',
#  'for sweet squash , drizzle melted honey , butter , grated piloncillo over each cut squash piece',
#  'season with sweet mexican spice mix',
#  'bake at 350 degrees , again depending on size , for 40 minutes up to an hour , until a fork can easily pierce the skin',
#  'be careful not to burn the squash especially if you opt to use sugar or butter',
#  'if you feel more comfortable , cover the squash with aluminum foil the first half hour , give or take , of baking',
#  'if desired , season with salt']

# %%
recipes['ingredients'] = recipes['ingredients'].apply(ast.literal_eval)
recipes['ingredients'][0]
# Out:
# ['winter squash',
#  'mexican seasoning',
#  'mixed spice',
#  'honey',
#  'butter',
#  'olive oil',
#  'salt']

# %%
ingredients = recipes['ingredients'].explode()
ing_counts = ingredients.value_counts()
ing_counts
# Out:
# ingredients
# salt                         83781
# butter                       53788
# sugar                        43419
# onion                        38168
# water                        34060
#                              ...
# low-sodium wheat crackers        1
# capicola-mozzarella roll         1
# citrus ponzu soy sauce           1
# asiago cheese rolls              1
# nepitella                        1
# Name: count, Length: 14758, dtype: int64

# %%
ing_filetered = ing_counts[ing_counts > 2000]
ing_filetered
# Out:
# ingredients
# salt                83781
# butter              53788
# sugar               43419
# onion               38168
# water               34060
#                     ...
# beef broth           2045
# shallot              2029
# lemon, juice of      2019
# ground coriander     2012
# fresh mushrooms      2009
# Name: count, Length: 173, dtype: int64

# %%
for ing in list(ing_filetered.index):
    if 'chicken' in ing:
        print(ing)
# Out:
# chicken broth
# chicken stock
# boneless skinless chicken breasts
# chicken breasts
# chicken

# %%
def check_values(row, values):
    return pd.Series({value: value in row for value in values})

# %%
new_cols_ing = recipes['ingredients'].apply(check_values, values=list(ing_filetered.index))
new_cols_ing
# Out:
#          salt  butter  sugar  onion  water   eggs  olive oil  flour  \
# 0        True    True  False  False  False  False       True  False
# 1       False   False  False  False  False   True      False  False
# 2        True   False  False  False   True  False      False  False
# 3        True   False  False  False  False  False       True  False
# 4        True   False   True  False  False  False      False  False
# ...       ...     ...    ...    ...    ...    ...        ...    ...
# 231632  False   False   True   True  False  False       True  False
# 231633   True   False  False  False  False  False      False  False
# 231634   True   False  False  False  False  False      False  False
# 231635  False    True  False  False  False  False      False  False
# 231636  False   False  False  False  False   True      False   True
#
#         garlic cloves   milk  ...  cooking spray  skim milk  cream  chicken  \
# 0               False  False  ...          False      False  False    False
# 1               False   True  ...          False      False  False    False
# 2               False  False  ...          False      False  False    False
# 3               False  False  ...          False      False  False    False
# 4               False  False  ...          False      False  False    False
# ...               ...    ...  ...            ...        ...    ...      ...
# 231632           True  False  ...          False      False  False    False
# 231633          False  False  ...          False      False  False    False
# 231634          False  False  ...          False      False  False    False
# 231635          False  False  ...          False      False  False    False
# 231636          False  False  ...          False      False  False    False
#
#         warm water  beef broth  shallot  lemon, juice of  ground coriander  \
# 0            False       False    False            False             False
# 1            False       False    False            False             False
# 2            False       False    False            False             False
# 3            False       False    False            False             False
# 4            False       False    False            False             False
# ...            ...         ...      ...              ...               ...
# 231632       False       False    False            False             False
# 231633       False       False    False            False             False
# 231634       False       False    False            False             False
# 231635       False       False    False            False             False
# 231636       False       False    False            False             False
#
#         fresh mushrooms
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...                 ...
# 231632            False
# 231633            False
# 231634            False
# 231635            False
# 231636            False
#
# [226657 rows x 173 columns]

# %%
new_cols_tag = recipes['tags'].apply(check_values, values=list(tags_filtered.index))
new_cols_tag
# Out:
#         preparation  time-to-make  course  main-ingredient  dietary   easy  \
# 0              True          True    True             True     True   True
# 1              True          True    True             True     True   True
# 2              True          True    True            False     True  False
# 3              True          True    True             True     True   True
# 4              True          True    True             True     True  False
# ...             ...           ...     ...              ...      ...    ...
# 231632         True          True    True             True    False   True
# 231633         True          True    True            False     True   True
# 231634         True          True    True             True    False   True
# 231635         True          True    True            False     True  False
# 231636         True          True    True            False     True  False
#
#         occasion  cuisine  low-in-something  main-dish  ...  \
# 0           True     True             False      False  ...
# 1           True     True             False       True  ...
# 2          False    False             False       True  ...
# 3           True    False             False      False  ...
# 4           True     True             False      False  ...
# ...          ...      ...               ...        ...  ...
# 231632     False     True             False      False  ...
# 231633     False    False             False      False  ...
# 231634     False    False             False      False  ...
# 231635     False    False             False      False  ...
# 231636      True    False             False      False  ...
#
#         free-of-something  condiments-etc  high-in-something  soups-stews  \
# 0                   False           False              False        False
# 1                   False           False              False        False
# 2                   False           False              False        False
# 3                   False           False              False        False
# 4                   False            True              False        False
# ...                   ...             ...                ...          ...
# 231632              False           False              False         True
# 231633              False            True              False        False
# 231634              False           False              False        False
# 231635              False           False               True        False
# 231636              False           False              False        False
#
#         technique  beverages  sweet  savory  potluck  potatoes
# 0           False      False  False   False    False     False
# 1           False      False  False   False    False     False
# 2           False      False  False   False    False     False
# 3           False      False  False   False    False      True
# 4            True      False  False   False    False     False
# ...           ...        ...    ...     ...      ...       ...
# 231632      False      False  False   False    False     False
# 231633      False      False  False   False    False     False
# 231634      False      False  False   False    False     False
# 231635      False      False  False   False    False     False
# 231636      False      False   True   False    False     False
#
# [226657 rows x 80 columns]

# %%
tags_ings = pd.concat([new_cols_ing, new_cols_tag], axis=1)
tags_ings.head()
# Out:
#     salt  butter  sugar  onion  water   eggs  olive oil  flour  garlic cloves  \
# 0   True    True  False  False  False  False       True  False          False
# 1  False   False  False  False  False   True      False  False          False
# 2   True   False  False  False   True  False      False  False          False
# 3   True   False  False  False  False  False       True  False          False
# 4   True   False   True  False  False  False      False  False          False
#
#     milk  ...  free-of-something  condiments-etc  high-in-something  \
# 0  False  ...              False           False              False
# 1   True  ...              False           False              False
# 2  False  ...              False           False              False
# 3  False  ...              False           False              False
# 4  False  ...              False            True              False
#
#    soups-stews  technique  beverages  sweet  savory  potluck  potatoes
# 0        False      False      False  False   False    False     False
# 1        False      False      False  False   False    False     False
# 2        False      False      False  False   False    False     False
# 3        False      False      False  False   False    False      True
# 4        False       True      False  False   False    False     False
#
# [5 rows x 253 columns]

# %%
recipes.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  n_steps  \
# 0  [60-minutes-or-less, time-to-make, course, mai...       11
# 1  [30-minutes-or-less, time-to-make, course, mai...        9
# 2  [time-to-make, course, preparation, main-dish,...        6
# 3  [60-minutes-or-less, time-to-make, course, mai...       11
# 4  [weeknight, time-to-make, course, main-ingredi...        5
#
#                                                steps  \
# 0  [make a choice and proceed with recipe, depend...
# 1  [preheat oven to 425 degrees f, press dough in...
# 2  [brown ground beef in large pot, add chopped o...
# 3  [place potatoes in a large pot of lightly salt...
# 4  [mix all ingredients& boil for 2 1 / 2 hours ,...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients  calories  \
# 0  [winter squash, mexican seasoning, mixed spice...              7      51.5
# 1  [prepared pizza crust, sausage patty, eggs, mi...              6     173.4
# 2  [ground beef, yellow onions, diced tomatoes, t...             13     269.8
# 3  [spreadable cheese with garlic and herbs, new ...             11     368.1
# 4  [tomato juice, apple cider vinegar, sugar, sal...              8     352.9
#
#     fat  sugar  sodium  protein  saturated_fat  carbohydrates
# 0   0.0   13.0     0.0      2.0            0.0            4.0
# 1  18.0    0.0    17.0     22.0           35.0            1.0
# 2  22.0   32.0    48.0     39.0           27.0            5.0
# 3  17.0   10.0     2.0     14.0            8.0           20.0
# 4   1.0  337.0    23.0      3.0            0.0           28.0

# %%
recipes_feat = recipes.drop(columns=['contributor_id', 'submitted', 'tags', 'steps', 'description',
                                     'ingredients', 'name', 'n_steps', 'n_ingredients', 'minutes'])
recipes_feat = pd.concat([recipes_feat, tags_ings], axis=1)
recipes_feat.head()
# Out:
#        id  calories   fat  sugar  sodium  protein  saturated_fat  \
# 0  137739      51.5   0.0   13.0     0.0      2.0            0.0
# 1   31490     173.4  18.0    0.0    17.0     22.0           35.0
# 2  112140     269.8  22.0   32.0    48.0     39.0           27.0
# 3   59389     368.1  17.0   10.0     2.0     14.0            8.0
# 4   44061     352.9   1.0  337.0    23.0      3.0            0.0
#
#    carbohydrates   salt  butter  ...  free-of-something  condiments-etc  \
# 0            4.0   True    True  ...              False           False
# 1            1.0  False   False  ...              False           False
# 2            5.0   True   False  ...              False           False
# 3           20.0   True   False  ...              False           False
# 4           28.0   True   False  ...              False            True
#
#    high-in-something  soups-stews  technique  beverages  sweet  savory  \
# 0              False        False      False      False  False   False
# 1              False        False      False      False  False   False
# 2              False        False      False      False  False   False
# 3              False        False      False      False  False   False
# 4              False        False       True      False  False   False
#
#    potluck  potatoes
# 0    False     False
# 1    False     False
# 2    False     False
# 3    False      True
# 4    False     False
#
# [5 rows x 261 columns]

# %%
recipes_feat['name']
# Out:
# 0           arriba   baked winter squash mexican style
# 1                     a bit different  breakfast pizza
# 2                            all in the kitchen  chili
# 3                                   alouette  potatoes
# 4                   amish  tomato ketchup  for canning
#                               ...
# 231632                                     zydeco soup
# 231633                                zydeco spice mix
# 231634                       zydeco ya ya deviled eggs
# 231635          cookies by design   cookies on a stick
# 231636    cookies by design   sugar shortbread cookies
# Name: name, Length: 226657, dtype: object

# %%
duplicate_columns = recipes_feat.columns[recipes_feat.columns.duplicated()].tolist()
duplicate_columns
# Out:
# ['sugar',
#  'chicken',
#  'cheese',
#  'pasta',
#  'potatoes',
#  'eggs',
#  'nuts',
#  'rice',
#  'tomatoes',
#  'onions',
#  'apples',
#  'shrimp',
#  'mushrooms',
#  'yeast',
#  'carrots',
#  'corn',
#  'strawberries',
#  'broccoli',
#  'bananas',
#  'spinach',
#  'bacon',
#  'lemon',
#  'coconut',
#  'ham',
#  'spaghetti',
#  'asparagus',
#  'blueberries',
#  'cauliflower']

# %%
len(duplicate_columns)
# Out:
# 28

# %%
column_counts = recipes_feat.columns.value_counts()
print("\nColumn name counts:")
print(column_counts)
# Out:
# Column name counts:
# onions              2
# corn                2
# spinach             2
# apples              2
# spaghetti           2
#                    ..
# swiss cheese        1
# almond extract      1
# fresh mushrooms     1
# ground coriander    1
# wedding             1
# Name: count, Length: 549, dtype: int64

# %%
recipes_feat_clean = recipes_feat.loc[:, ~recipes_feat.columns.duplicated()]

# %%
recipes_feat_clean.head()
# Out:
#        id  calories   fat  sugar  sodium  protein  saturated_fat  \
# 0  137739      51.5   0.0   13.0     0.0      2.0            0.0
# 1   31490     173.4  18.0    0.0    17.0     22.0           35.0
# 2  112140     269.8  22.0   32.0    48.0     39.0           27.0
# 3   59389     368.1  17.0   10.0     2.0     14.0            8.0
# 4   44061     352.9   1.0  337.0    23.0      3.0            0.0
#
#    carbohydrates   salt  butter  ...  served-hot  free-of-something  \
# 0            4.0   True    True  ...       False              False
# 1            1.0  False   False  ...       False              False
# 2            5.0   True   False  ...       False              False
# 3           20.0   True   False  ...        True              False
# 4           28.0   True   False  ...       False              False
#
#    condiments-etc  high-in-something  soups-stews  technique  beverages  \
# 0           False              False        False      False      False
# 1           False              False        False      False      False
# 2           False              False        False      False      False
# 3           False              False        False      False      False
# 4            True              False        False       True      False
#
#    sweet  savory  potluck
# 0  False   False    False
# 1  False   False    False
# 2  False   False    False
# 3  False   False    False
# 4  False   False    False
#
# [5 rows x 257 columns]

# %%
recipes_feat_clean.duplicated().sum()
# Out:
# np.int64(0)

# %%
column_counts = recipes_feat_clean.columns.value_counts()
print("\nColumn name counts:")
print(column_counts)
# Out:
# Column name counts:
# id              1
# for-1-or-2      1
# healthy-2       1
# comfort-food    1
# european        1
#                ..
# warm water      1
# chicken         1
# cream           1
# skim milk       1
# wedding         1
# Name: count, Length: 549, dtype: int64

# %%
# Save feature matrix as csv
recipes_feat_clean.to_parquet('data/recipes_feat.parquet')

# %%
recipes_new = recipes.drop(columns=['name', 'steps', 'description', 'contributor_id', 'submitted', 'n_ingredients', 
                                    'n_steps', 'minutes', 'calories', 'fat', 'sugar', 'sodium', 'protein',
                                    'saturated_fat', 'carbohydrates'])
recipes_new.head()
# Out:
#        id                                               tags  \
# 0  137739  [60-minutes-or-less, time-to-make, course, mai...
# 1   31490  [30-minutes-or-less, time-to-make, course, mai...
# 2  112140  [time-to-make, course, preparation, main-dish,...
# 3   59389  [60-minutes-or-less, time-to-make, course, mai...
# 4   44061  [weeknight, time-to-make, course, main-ingredi...
#
#                                          ingredients
# 0  [winter squash, mexican seasoning, mixed spice...
# 1  [prepared pizza crust, sausage patty, eggs, mi...
# 2  [ground beef, yellow onions, diced tomatoes, t...
# 3  [spreadable cheese with garlic and herbs, new ...
# 4  [tomato juice, apple cider vinegar, sugar, sal...

# %%
recipes_new.to_parquet('data/recipes.parquet')

# %%
recipes_steps = recipes.drop(columns=['contributor_id', 'submitted', 'n_ingredients', 'n_steps', 'minutes', 'calories', 'fat',
                                      'sugar', 'sodium', 'protein', 'saturated_fat', 'carbohydrates', 'tags'])
recipes_steps.head()
# Out:
#                                          name      id  \
# 0  arriba   baked winter squash mexican style  137739
# 1            a bit different  breakfast pizza   31490
# 2                   all in the kitchen  chili  112140
# 3                          alouette  potatoes   59389
# 4          amish  tomato ketchup  for canning   44061
#
#                                                steps  \
# 0  [make a choice and proceed with recipe, depend...
# 1  [preheat oven to 425 degrees f, press dough in...
# 2  [brown ground beef in large pot, add chopped o...
# 3  [place potatoes in a large pot of lightly salt...
# 4  [mix all ingredients& boil for 2 1 / 2 hours ,...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients
# 0  [winter squash, mexican seasoning, mixed spice...
# 1  [prepared pizza crust, sausage patty, eggs, mi...
# 2  [ground beef, yellow onions, diced tomatoes, t...
# 3  [spreadable cheese with garlic and herbs, new ...
# 4  [tomato juice, apple cider vinegar, sugar, sal...

# %%
recipes_steps.to_parquet('data/recipes_steps.parquet')

# %%
ing_selected = ['chicken', 'onions', 'carrots']

# %%
def search_ing(row_ingredients, ing_selected):
    row_set = set(row_ingredients)
    search_set = set()
    for ing in ing_selected:
        for row_ing in row_ingredients:
            if row_ing in ing or ing in row_ing:
                search_set.add(row_ing)
    found = row_set.intersection(search_set)
    return list(found)

# %%
recipes_new['all_ings'] = recipes_new['ingredients'].apply(search_ing, ing_selected=ing_selected)
recipes_new.head()
# Out:
#        id                                               tags  \
# 0  137739  [60-minutes-or-less, time-to-make, course, mai...
# 1   31490  [30-minutes-or-less, time-to-make, course, mai...
# 2  112140  [time-to-make, course, preparation, main-dish,...
# 3   59389  [60-minutes-or-less, time-to-make, course, mai...
# 4   44061  [weeknight, time-to-make, course, main-ingredi...
#
#                                          ingredients         all_ings  match
# 0  [winter squash, mexican seasoning, mixed spice...               []  False
# 1  [prepared pizza crust, sausage patty, eggs, mi...               []  False
# 2  [ground beef, yellow onions, diced tomatoes, t...  [yellow onions]  False
# 3  [spreadable cheese with garlic and herbs, new ...               []  False
# 4  [tomato juice, apple cider vinegar, sugar, sal...               []  False

# %%
recipes_new[recipes_new['all_ings'].apply(len) >= len(ing_selected)]
# Out:
#             id                                               tags  \
# 29       44123  [weeknight, time-to-make, course, main-ingredi...
# 85      103948  [time-to-make, course, main-ingredient, prepar...
# 134      69190  [time-to-make, course, main-ingredient, cuisin...
# 159     445026  [weeknight, time-to-make, course, main-ingredi...
# 165     269984  [time-to-make, course, preparation, occasion, ...
# ...        ...                                                ...
# 231496  250050  [60-minutes-or-less, time-to-make, course, mai...
# 231558  415406  [weeknight, 60-minutes-or-less, time-to-make, ...
# 231579  464576  [time-to-make, course, main-ingredient, cuisin...
# 231590  326419  [bacon, 15-minutes-or-less, time-to-make, cour...
# 231626   61748  [60-minutes-or-less, time-to-make, course, mai...
#
#                                               ingredients  \
# 29      [unsalted butter, carrot, onion, celery, brocc...
# 85      [boneless skinless chicken thighs, all-purpose...
# 134     [cream of chicken soup, cream of celery soup, ...
# 159     [vegetable oil, all-purpose flour, onion, gree...
# 165     [chicken breasts, baby carrots, celery, white ...
# ...                                                   ...
# 231496  [ziti pasta, chicken sausage, olive oil, zucch...
# 231558  [potatoes, onions, chicken broth, chicken stoc...
# 231579  [sweet italian sausage, onion, garlic cloves, ...
# 231590  [bacon, onions, garlic cloves, celery, carrot,...
# 231626  [onions, red onions, fresh garlic, olive oil, ...
#
#                                                  all_ings  match
# 29         [smoked chicken, onion, carrot, chicken stock]   True
# 85      [boneless skinless chicken thighs, onion, chic...   True
# 134              [cream of chicken soup, onions, carrots]   True
# 159     [onion, low sodium chicken broth, cooked chicken]   True
# 165        [chicken breasts, baby carrots, chicken stock]   True
# ...                                                   ...    ...
# 231496  [onions, fat-free low-sodium chicken broth, ch...   True
# 231558        [onions, chicken stock cube, chicken broth]   True
# 231579                    [onion, chicken broth, carrots]   True
# 231590  [onions, low-sodium low-fat chicken broth, car...   True
# 231626                [red onions, onions, chicken broth]   True
#
# [6856 rows x 5 columns]

# %%
def check_ingredients_df(row):
    ingredients = ing_selected
    all_ings = row
    
    # If all_ings is empty, return False
    if not all_ings:
        return False
    
    # Join all ingredients into a single lowercase string
    ingredients_str = ' '.join(str(ing).lower() for ing in all_ings)
    
    # Check each item in all_ings
    for item in ingredients:
        item = item.strip('s')
        if item not in ingredients_str:
            return False
    
    # If we've made it through all items without returning False, return True
    return True

# %%
recipes_new['match'] = recipes_new['all_ings'].apply(check_ingredients_df)

# %%
recipes_new
# Out:
#             id                                               tags  \
# 0       137739  [60-minutes-or-less, time-to-make, course, mai...
# 1        31490  [30-minutes-or-less, time-to-make, course, mai...
# 2       112140  [time-to-make, course, preparation, main-dish,...
# 3        59389  [60-minutes-or-less, time-to-make, course, mai...
# 4        44061  [weeknight, time-to-make, course, main-ingredi...
# ...        ...                                                ...
# 231632  486161  [ham, 60-minutes-or-less, time-to-make, course...
# 231633  493372  [15-minutes-or-less, time-to-make, course, pre...
# 231634  308080  [60-minutes-or-less, time-to-make, course, mai...
# 231635  298512  [30-minutes-or-less, time-to-make, course, pre...
# 231636  298509  [30-minutes-or-less, time-to-make, course, pre...
#
#                                               ingredients  \
# 0       [winter squash, mexican seasoning, mixed spice...
# 1       [prepared pizza crust, sausage patty, eggs, mi...
# 2       [ground beef, yellow onions, diced tomatoes, t...
# 3       [spreadable cheese with garlic and herbs, new ...
# 4       [tomato juice, apple cider vinegar, sugar, sal...
# ...                                                   ...
# 231632  [celery, onion, green sweet pepper, garlic clo...
# 231633  [paprika, salt, garlic powder, onion powder, d...
# 231634  [hard-cooked eggs, mayonnaise, dijon mustard, ...
# 231635  [butter, eagle brand condensed milk, light bro...
# 231636  [granulated sugar, shortening, eggs, flour, cr...
#
#                                  all_ings  match
# 0                                      []  False
# 1                                      []  False
# 2                         [yellow onions]  False
# 3                                      []  False
# 4                                      []  False
# ...                                   ...    ...
# 231632  [onion, low sodium chicken broth]  False
# 231633                                 []  False
# 231634                                 []  False
# 231635                                 []  False
# 231636                                 []  False
#
# [226657 rows x 5 columns]

# %%
recipes_test = recipes_new[recipes_new['match'] == True]

# %%
recipes_test
# Out:
#             id                                               tags  \
# 1361    111257  [30-minutes-or-less, time-to-make, course, mai...
# 1363     28670  [lactose, 30-minutes-or-less, time-to-make, co...
# 4762     85648  [30-minutes-or-less, time-to-make, course, mai...
# 9170    242393  [30-minutes-or-less, time-to-make, course, mai...
# 9417     75654  [30-minutes-or-less, time-to-make, course, mai...
# ...        ...                                                ...
# 223733  373053  [30-minutes-or-less, time-to-make, course, mai...
# 227747   86461  [30-minutes-or-less, time-to-make, course, mai...
# 228381  185775  [30-minutes-or-less, time-to-make, course, mai...
# 229569  353950  [30-minutes-or-less, time-to-make, course, mai...
# 230721  365929  [30-minutes-or-less, time-to-make, course, mai...
#
#                                               ingredients  \
# 1361    [chicken breast tenders, olive oil, butter, ru...
# 1363    [extra virgin olive oil, carrots, parsnip, oni...
# 4762    [butter, carrots, green onions, chicken broth,...
# 9170    [rice noodles, chicken, carrot, green bell pep...
# 9417    [ramen noodles, sunflower seeds, slivered almo...
# ...                                                   ...
# 223733  [chicken breasts, pineapple juice, coconut mil...
# 227747  [bok choy, red cabbage, carrot, cilantro, appl...
# 228381  [chicken breasts, thin spaghetti, fat free chi...
# 229569  [rice, chicken thighs, onion, frozen broccoli ...
# 230721  [fresh mushrooms, onion, celery, carrot, butte...
#
#                                                  all_ings  match  tag_match
# 1361    [onion, chicken breast tenders, chicken broth,...   True       True
# 1363    [onion, chicken breast tenders, chicken stock,...   True       True
# 4762    [chicken broth, green onions, cooked chicken, ...   True       True
# 9170                      [chicken, green onions, carrot]   True       True
# 9417    [green onions, carrot, boneless skinless chick...   True       True
# ...                                                   ...    ...        ...
# 223733  [onion, chicken breasts, baby carrots, chicken...   True       True
# 227747             [green onions, carrot, cooked chicken]   True       True
# 228381  [fat free chicken broth, green onions, carrot,...   True       True
# 229569  [onion, chicken thighs, frozen broccoli carrot...   True       True
# 230721     [onion, chicken broth, cooked chicken, carrot]   True       True
#
# [134 rows x 6 columns]

# %%
def all_tags_present(item_tags, selected):
    return all(string in item_tags for string in selected)

# %%
recipes_test['tag_match'] = recipes_test['tags'].apply(all_tags_present, selected=['poultry', '30-minutes-or-less'])
# Out:
# /var/folders/0c/wkrr_xjn2xz65fx41rj45h6w0000gp/T/ipykernel_16040/1595101780.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recipes_test['tag_match'] = recipes_test['tags'].apply(all_tags_present, selected=['poultry', '30-minutes-or-less'])

# %%
recipes_test = recipes_test[recipes_test['tag_match'] == True]

# %%
recipes_id = recipes_test['id'].values
recipes_id
# Out:
# array([111257,  28670,  85648, 242393,  75654, 512041, 154765, 350695,
#        126137, 495366,  38838,  25344, 122536, 272825, 284101, 502492,
#        205325, 130650, 192865, 298171, 395452, 197276, 230786, 263211,
#         82503,  13334, 136175,  27800, 223273, 459462, 380859, 364039,
#        275001, 195625, 477720, 320081, 138557, 146269, 151810,  99429,
#        234223, 168166, 185427, 203518, 486282, 389536, 207439, 367935,
#        403121, 148678, 143397, 439096, 167731,  23282, 350097, 272306,
#        222005, 486780, 304772, 417193, 284265, 185367, 272427,  29979,
#        243330, 213006, 125190, 298063, 194892, 372815,  58905,  89289,
#        135142, 144104, 384863,  38221,  19230, 447472, 412883, 297691,
#        243324,  62263, 280562, 406539,  17156, 237544,  30433,  36944,
#        282484, 535072, 101096,  36172, 133711, 223812, 190712, 212198,
#        422001, 488678, 381540, 228028, 487487, 154398, 210264, 273121,
#        120558, 297336, 384435, 233158, 128399,  64584, 151845, 132682,
#        110977, 166968, 293768, 111624, 247597, 219934, 188180, 342790,
#        497101, 120226, 230803, 127805, 204181, 392687, 197095,  70727,
#        472325, 373053,  86461, 185775, 353950, 365929])

# %%
len(recipes_id)
# Out:
# 134

# %%
recipes_steps
# Out:
#                                                 name      id  \
# 0         arriba   baked winter squash mexican style  137739
# 1                   a bit different  breakfast pizza   31490
# 2                          all in the kitchen  chili  112140
# 3                                 alouette  potatoes   59389
# 4                 amish  tomato ketchup  for canning   44061
# ...                                              ...     ...
# 231632                                   zydeco soup  486161
# 231633                              zydeco spice mix  493372
# 231634                     zydeco ya ya deviled eggs  308080
# 231635        cookies by design   cookies on a stick  298512
# 231636  cookies by design   sugar shortbread cookies  298509
#
#                                                     steps  \
# 0       [make a choice and proceed with recipe, depend...
# 1       [preheat oven to 425 degrees f, press dough in...
# 2       [brown ground beef in large pot, add chopped o...
# 3       [place potatoes in a large pot of lightly salt...
# 4       [mix all ingredients& boil for 2 1 / 2 hours ,...
# ...                                                   ...
# 231632  [heat oil in a 4-quart dutch oven, add celery ...
# 231633          [mix all ingredients together thoroughly]
# 231634  [in a bowl , combine the mashed yolks and mayo...
# 231635  [place melted butter in a large mixing bowl an...
# 231636  [whip sugar and shortening in a large bowl , a...
#
#                                               description
# 0       autumn is my favorite time of year to cook! th...
# 1       this recipe calls for the crust to be prebaked...
# 2       this modified version of 'mom's' chili was a h...
# 3       this is a super easy, great tasting, make ahea...
# 4       my dh's amish mother raised him on this recipe...
# ...                                                   ...
# 231632  this is a delicious soup that i originally fou...
# 231633    this spice mix will make your taste buds dance!
# 231634                          deviled eggs, cajun-style
# 231635  i've heard of the 'cookies by design' company,...
# 231636  i've heard of the 'cookies by design' company,...
#
# [226657 rows x 4 columns]

# %%
recipes_steps_rec = recipes_steps[recipes_steps['id'].isin(recipes_id)]
recipes_steps_rec
# Out:
#                                                      name      id  \
# 1361                      30 minute chicken and dumplings  111257
# 1363    30 minute chicken noodle soup  from foodtv  ra...   28670
# 4762                 amazingly simple chicken noodle soup   85648
# 9170                           asian chicken noodle salad  242393
# 9417                       asian ramen salad with chicken   75654
# ...                                                   ...     ...
# 223733               viv s pina colada chicken with salsa  373053
# 227747  winter chicken salad with chipotle cream dressing   86461
# 228381                     ww 2 point chicken noodle soup  185775
# 229569  yoshinoya style teriyaki chicken and vegetable...  353950
# 230721                        zippy chicken mushroom soup  365929
#
#                                                     steps  \
# 1361    [dice tenders into bite size pieces and set as...
# 1363    [place a large pot over moderate heat and add ...
# 4762    [cook carrots in melted butter 4 min, stir in ...
# 9170    [prepare noodles according to package directio...
# 9417    [place crushed ramen noodles , sunflower seeds...
# ...                                                   ...
# 223733  [mark chicken breast on hot grill & cook until...
# 227747  [in a bowl , combine all ingredients but parsl...
# 228381  [cut chicken into bite size pieces, saut in a ...
# 229569  [cook rice according to directions, slice onio...
# 230721  [in a dutch oven , saute the mushrooms , onion...
#
#                                               description
# 1361    this is a rachel ray recipe i had in my file f...
# 1363                                from show of 5/16/02.
# 4762    so simple, so tasty, so soothing!!! a classic ...
# 9170    this is the first time i ever used rice noodle...
# 9417    a nice crunchy salad with a great tangy dressi...
# ...                                                   ...
# 223733  another recipe from our stay in puerto rico.  ...
# 227747  an adopted recipe originally posted by mean ch...
# 228381  this recipe i got at a weight watchers meeting...
# 229569  i had food at a yoshinoya restaurant in califo...
# 230721  this is a recipe i found in a taste of home ma...
#
# [134 rows x 4 columns]

# %%
rec = recipes_steps_rec[recipes_steps_rec['id'] == 85648]

# %%
rec['steps'].values[0]
# Out:
# ['cook carrots in melted butter 4 min',
#  'stir in onion , broth and bay leaf',
#  'season with salt and pepper to taste',
#  'bring to a boil , then simmer 5 min until carrots are almost tender',
#  'return to a boil',
#  'add noodles , chicken , peas and simmer until noodles are tender',
#  'enjoy']

# %%
rec['name'].values[0]
# Out:
# 'amazingly simple chicken noodle soup'

# %%
name = rec['name'].values[0].replace(' ', '-')
name
# Out:
# 'amazingly-simple-chicken-noodle-soup'

# %%
link = f"https://www.food.com/recipe/{name}-{rec['id'].values[0]}"
link
# Out:
# 'https://www.food.com/recipe/amazingly-simple-chicken-noodle-soup-85648'

# %%
rec_feat = recipes_feat_clean[recipes_feat_clean['id'] == 144230]
rec_feat = rec_feat.drop(columns=['id']).values.reshape(1, -1)

cosine_sim = cosine_similarity(rec_feat, recipes_feat_clean.drop(columns=['id']))
sim_scores = list(zip(recipes_feat_clean['id'].values, cosine_sim[0]))
sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
sim_scores = sim_scores[0:6]
rec_indices = [i[0] for i in sim_scores]

# %%
sim_scores
# Out:
# [(np.int64(144230), np.float64(0.9999999999999997)),
#  (np.int64(188904), np.float64(0.9999193030770934)),
#  (np.int64(335165), np.float64(0.9999124010158112)),
#  (np.int64(380464), np.float64(0.9998212309433744)),
#  (np.int64(35264), np.float64(0.9997718227179002)),
#  (np.int64(78321), np.float64(0.9997654888856027))]

# %%
recipes_new[recipes_new['id'].isin(rec_indices)]
# Out:
#            id                                               tags  \
# 24627  188904  [30-minutes-or-less, time-to-make, course, pre...
# 29585  335165  [bacon, 15-minutes-or-less, time-to-make, cour...
# 73280   78321  [30-minutes-or-less, time-to-make, course, mai...
# 74889   35264  [15-minutes-or-less, time-to-make, course, pre...
# 99149  380464  [weeknight, 30-minutes-or-less, time-to-make, ...
#
#                                              ingredients
# 24627  [black pepper, salt, butter, golden brown suga...
# 29585  [broccoli florets, red onion, sharp cheddar ch...
# 73280  [vegetable oil, onion, white wine vinegar, hon...
# 74889  [coleslaw mix, red pepper, green onions, fresh...
# 99149  [eggplants, chinese five spice powder, onion p...

# %%
rec_indices
# Out:
# [np.int64(24841),
#  np.int64(314126),
#  np.int64(417682),
#  np.int64(456939),
#  np.int64(27121)]

# %%
recipes_new.shape
# Out:
# (226657, 3)

# %%
sim_scores
# Out:
# [(160502, np.float64(0.9988458013016529)),
#  (61857, np.float64(0.9983187001400087)),
#  (95262, np.float64(0.99830700479747)),
#  (120834, np.float64(0.9982398338863303)),
#  (11523, np.float64(0.9982158183362595))]

# %%
recipes_new.shape
# Out:
# (226657, 3)

# %%
recipes_steps[recipes_steps['id'].isin(rec_indices)]
# Out:
#                                                     name      id  \
# 24627                               black pepper almonds  188904
# 29585                    broccoli with cranberries salad  335165
# 73280  dove s nest turkey  red grape   bleu cheese sa...   78321
# 74889                                easy asian coleslaw   35264
# 99149  grilled japanese eggplant with an asian vinaig...  380464
#
#                                                    steps  \
# 24627  [preheat oven to 350 degrees f, line large bak...
# 29585  [for the salad ~ in a large salad bowl , mix a...
# 73280  [to make dressing , combine the oil , onion , ...
# 74889  [mix salad ingredients in large bowl, mix dres...
# 99149  [wash eggplants and pat dry with paper towels ...
#
#                                              description  \
# 24627  these are good with cocktails. recipe from bon...
# 29585  another recipe that comes from the 2004 cookbo...
# 73280  this is another favorite from my favorite waxa...
# 74889  great change from the mayo type and very easy ...
# 99149  high in fiber and low in calories, grilled egg...
#
#                                              ingredients
# 24627  [black pepper, salt, butter, golden brown suga...
# 29585  [broccoli florets, red onion, sharp cheddar ch...
# 73280  [vegetable oil, onion, white wine vinegar, hon...
# 74889  [coleslaw mix, red pepper, green onions, fresh...
# 99149  [eggplants, chinese five spice powder, onion p...

# %%
recipes_feat_clean[recipes_feat_clean['id'].isin(rec_indices)]
# Out:
#            id  calories    fat  sugar  sodium  protein  saturated_fat  \
# 24627  188904    1136.4  135.0  180.0    79.0     61.0           81.0
# 29585  335165     546.2   57.0   91.0    38.0     33.0           44.0
# 73280   78321     603.4   74.0  103.0    35.0     34.0           46.0
# 74889   35264     236.8   27.0   37.0    15.0     12.0           15.0
# 99149  380464     450.9   49.0   74.0    31.0     19.0           33.0
#
#        carbohydrates   salt  butter  ...  served-hot  free-of-something  \
# 24627           24.0   True    True  ...       False              False
# 29585           13.0   True   False  ...       False              False
# 73280           10.0  False   False  ...       False              False
# 74889            5.0  False   False  ...       False              False
# 99149           12.0  False   False  ...       False              False
#
#        condiments-etc  high-in-something  soups-stews  technique  beverages  \
# 24627           False               True        False      False      False
# 29585           False              False        False      False      False
# 73280           False              False        False      False      False
# 74889           False              False        False      False      False
# 99149           False              False        False      False      False
#
#        sweet  savory  potluck
# 24627  False   False    False
# 29585  False   False    False
# 73280  False   False    False
# 74889  False   False    False
# 99149  False    True    False
#
# [5 rows x 257 columns]
